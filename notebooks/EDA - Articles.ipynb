# %%
import pandas as pd
import numpy as np
from itertools import combinations
from collections import Counter

# %%
df_articles = pd.read_csv('../data/raw/candidate_articles.csv')

# %% [markdown]
# # Which candidates share articles?

# %%
def process_query(df, acc, candidate_names=None):
    df.groupby('url').apply(lambda grp: shared_query(grp, acc))

def shared_query(grp, acc):
    if len(grp['query']):
        cand_names = grp['query'].sort_values().values
        for combo in combinations(cand_names, 2):
            acc[combo] += 1
            
def process_description(df, acc, candidate_names):
    df.description.map(lambda d: shared_description(d, acc, candidate_names))
            
def shared_description(desc, acc, candidate_names):
    if len(desc):
        for name in candidate_names:
            for pair in [x for x in candidate_names if x != name]:
                desc = desc.lower()
                if name in desc and pair in desc:
                    acc[(name, pair)] += 1
        

def find_shared_articles(article_df, shared_property):
    shared_articles = Counter()
    candidates = ['biden', 'bloomberg', 'buttigieg', 'klobuchar', 'sanders', 'warren']
    process_fns = {'query': process_query, 'desc': process_description}
    
    process_fns[shared_property](article_df, shared_articles, candidates)
    
    results_df = pd.DataFrame(np.zeros((6,6)), columns=candidates, index=candidates)
    
    for (k, j), v in shared_articles.items():
        results_df.loc[k.lower(), j.lower()] = v
        results_df.loc[j.lower(), k.lower()] = v
    
    return results_df

# %%
shared_articles_summary_by_desc = find_shared_articles(df_articles, 'desc')
shared_articles_summary_by_desc
# Out:
#            biden  bloomberg  buttigieg  klobuchar  sanders  warren
# biden        0.0       30.0       52.0       50.0    104.0    31.0
# bloomberg   30.0        0.0        0.0       16.0     66.0    49.0
# buttigieg   52.0        0.0        0.0       58.0    149.0    25.0
# klobuchar   50.0       16.0       58.0        0.0     41.0    15.0
# sanders    104.0       66.0      149.0       41.0      0.0    52.0
# warren      31.0       49.0       25.0       15.0     52.0     0.0

# %%
shared_articles_summary_by_query = find_shared_articles(df_articles, 'query')
shared_articles_summary_by_query
# Out:
#            biden  bloomberg  buttigieg  klobuchar  sanders  warren
# biden      239.0      295.0      490.0      495.0    509.0   367.0
# bloomberg  295.0      172.0      249.0      323.0    312.0   277.0
# buttigieg  490.0      249.0      268.0      601.0    499.0   493.0
# klobuchar  495.0      323.0      601.0      272.0    487.0   490.0
# sanders    509.0      312.0      499.0      487.0    246.0   383.0
# warren     367.0      277.0      493.0      490.0    383.0   237.0

# %% [markdown]
# # Who's mentioned the most in the text?

# %%
candidates = ['biden', 'bloomberg', 'buttigieg', 'klobuchar', 'sanders', 'warren']

# %%
from nltk import word_tokenize
from collections import Counter
from functools import reduce

def count_mentions(text):
    if type(text) != str and np.isnan(text):
        return Counter()
    tokens = word_tokenize(text.lower())
    return Counter([w for w in tokens if w in candidates])

def sum_counts(counter1, counter2):
    for k, v in counter2.items():
        counter1[k] += v
    return counter1

def aggregate_counts(counts):
    return reduce(sum_counts, counts, Counter())

def get_total_mentions(article_texts):
    counts = [count_mentions(x) for x in article_texts]
    return aggregate_counts(counts)

# %%
df_articles['publishedAt'] = df_articles.publishedAt.map(pd.to_datetime)
df_articles['published_date'] = df_articles.publishedAt.map(lambda d: d.date())
grp = df_articles.drop_duplicates(subset=['url']).groupby('published_date').text.apply(get_total_mentions).reset_index()
mentions_by_day = grp.pivot(index='published_date', columns='level_1', values=['text'])
mentions_by_day
# Out:
#                 text
# level_1        biden bloomberg buttigieg klobuchar sanders warren
# published_date
# 2020-02-03      38.0       6.0      14.0      17.0    18.0   15.0
# 2020-02-04      38.0      17.0      42.0       9.0    28.0   16.0
# 2020-02-05      35.0       3.0       9.0       1.0    15.0    2.0
# 2020-02-06      27.0       4.0      14.0       7.0    17.0   25.0
# 2020-02-07      14.0       6.0      42.0      22.0    45.0    5.0
# 2020-02-08      76.0       6.0      71.0      32.0    72.0   25.0
# 2020-02-09      84.0       2.0      57.0      17.0    49.0   27.0
# 2020-02-10      31.0       2.0      15.0      10.0    27.0   78.0
# 2020-02-11      92.0      32.0      55.0      60.0    92.0   42.0
# 2020-02-12      38.0      24.0      55.0      91.0    90.0   44.0
# 2020-02-13      34.0      73.0      33.0      14.0    19.0   21.0
# 2020-02-14       5.0      29.0       2.0      20.0     1.0    NaN
# 2020-02-15       3.0       NaN       9.0       1.0     1.0    NaN
# 2020-02-16      33.0      21.0       9.0      26.0    11.0    3.0
# 2020-02-17       1.0      19.0       3.0       NaN    21.0    1.0
# 2020-02-18      33.0      54.0      50.0      53.0    25.0   12.0
# 2020-02-19      11.0      79.0      20.0      16.0    33.0   25.0
# 2020-02-20      38.0     180.0      80.0      68.0   103.0  104.0
# 2020-02-21      17.0      73.0       4.0       6.0    44.0   51.0
# 2020-02-22      47.0      78.0      13.0       8.0    73.0   20.0
# 2020-02-23      26.0      16.0      31.0      10.0   114.0   37.0
# 2020-02-24      15.0      22.0      28.0       NaN    48.0   13.0
# 2020-02-25      64.0      37.0       7.0       2.0    50.0   29.0
# 2020-02-26      36.0      83.0      19.0      24.0   126.0   45.0
# 2020-02-27      34.0      13.0       3.0       3.0    37.0   19.0
# 2020-02-28      31.0      54.0       2.0       1.0    66.0   35.0
# 2020-02-29      97.0      29.0      27.0       7.0    90.0   58.0
# 2020-03-01      82.0      28.0      10.0       8.0    62.0   17.0
# 2020-03-02      13.0       2.0      32.0      21.0    35.0   37.0
# 2020-03-03      82.0      90.0      22.0      11.0    42.0   29.0
# 2020-03-04       2.0       1.0       1.0       1.0     2.0    NaN

# %% [markdown]
# # By Candidate Query - Who is mentioned?

# %%
grp = df_articles.drop_duplicates(subset=['url', 'query']).groupby('query').text.apply(get_total_mentions).reset_index()
grp.pivot(index='query', columns='level_1', values='text')
# Out:
# level_1    biden  bloomberg  buttigieg  klobuchar  sanders  warren
# query
# Biden        787        175        199        111      485     107
# Bloomberg    230        778         82         75      366     164
# Buttigieg    361        127        500        162      483     204
# Klobuchar    334        183        322        447      460     260
# Sanders      297        177        230        129      715     124
# Warren       279        400        240        176      521     666

# %% [markdown]
# # By Candidate Query - Sentiment

# %% [markdown]
# ## Article Description

# %%
df_articles.drop_duplicates(subset=['url', 'query']).groupby('query').agg({'desc_sentiment': 'mean'}).reset_index()
# Out:
#        query  desc_sentiment
# 0      Biden        0.125579
# 1  Bloomberg        0.061001
# 2  Buttigieg        0.148596
# 3  Klobuchar        0.111751
# 4    Sanders        0.208267
# 5     Warren        0.046759

# %%
df_articles.drop_duplicates(subset=['url', 'query'])\
    .groupby('query').desc_sentiment.apply(lambda s: len(s[s < 0])).reset_index()\
    .rename(columns={'desc_sentiment': 'perc_neg_desc'})
# Out:
#        query  perc_neg_desc
# 0      Biden             27
# 1  Bloomberg             32
# 2  Buttigieg             21
# 3  Klobuchar             21
# 4    Sanders             20
# 5     Warren             32

# %% [markdown]
# ## Full Text

# %%
df_articles.drop_duplicates(subset=['url', 'query']).groupby('query').agg({'full_text_sentiment': 'mean'}).reset_index()
# Out:
#        query  full_text_sentiment
# 0      Biden             0.492979
# 1  Bloomberg             0.356160
# 2  Buttigieg             0.577375
# 3  Klobuchar             0.502355
# 4    Sanders             0.553658
# 5     Warren             0.495343

# %%
df_articles.drop_duplicates(subset=['url', 'query'])\
    .groupby('query').full_text_sentiment.apply(lambda s: len(s[s < 0])).reset_index()\
    .rename(columns={'full_text_sentiment': 'perc_neg_full_text'})
# Out:
#        query  perc_neg_full_text
# 0      Biden                  17
# 1  Bloomberg                  24
# 2  Buttigieg                   8
# 3  Klobuchar                  11
# 4    Sanders                  15
# 5     Warren                  15

# %% [markdown]
# # Tonality

# %% [markdown]
# ## Description

# %%
tones = ['analytical', 'anger', 'confident', 'fear', 'joy', 'sadness', 'tentative']

for t in tones:
    print(df_articles.drop_duplicates(subset=['url', 'query'])\
        .groupby('query').agg({f'desc_{t}': 'mean'}).reset_index())
# Out:
#        query  desc_analytical
# 0      Biden         0.690624
# 1  Bloomberg         0.758291
# 2  Buttigieg         0.719061
# 3  Klobuchar         0.713031
# 4    Sanders         0.731496
# 5     Warren         0.699561
#        query  desc_anger
# 0      Biden         NaN
# 1  Bloomberg    0.522450
# 2  Buttigieg    0.508238
# 3  Klobuchar         NaN
# 4    Sanders         NaN
# 5     Warren    0.508238
#        query  desc_confident
# 0      Biden        0.630238
# 1  Bloomberg        0.626416
# 2  Buttigieg        0.726172
# 3  Klobuchar        0.717560
# 4    Sanders        0.543435
# 5     Warren        0.768576
#        query  desc_fear
# 0      Biden        NaN
# 1  Bloomberg        NaN
# 2  Buttigieg   0.543700
# 3  Klobuchar   0.561740
# 4    Sanders   0.546448
# 5     Warren   0.552624
#        query  desc_joy
# 0      Biden  0.602183
# 1  Bloomberg  0.597751
# 2  Buttigieg  0.616279
# 3  Klobuchar  0.610986
# 4    Sanders  0.654158
# 5     Warren  0.621573
#        query  desc_sadness
# 0      Biden      0.589748
# 1  Bloomberg      0.523847
# 2  Buttigieg      0.574040
# 3  Klobuchar      0.547121
# 4    Sanders      0.544435
# 5     Warren      0.572876
#        query  desc_tentative
# 0      Biden        0.705536
# 1  Bloomberg        0.765520
# 2  Buttigieg        0.705440
# 3  Klobuchar        0.673200
# 4    Sanders        0.655382
# 5     Warren        0.701620

# %%
tones = ['analytical', 'anger', 'confident', 'fear', 'joy', 'sadness', 'tentative']

for t in tones:
    print(df_articles.drop_duplicates(subset=['url', 'query'])\
        .groupby('query')['desc_' + t].apply(lambda s: len(s[s > 0])).reset_index()\
        .rename(columns={f'desc_{t}': f'perc_{t}'}))
# Out:
#        query  perc_analytical
# 0      Biden               24
# 1  Bloomberg               23
# 2  Buttigieg               30
# 3  Klobuchar               30
# 4    Sanders               30
# 5     Warren               22
#        query  perc_anger
# 0      Biden           0
# 1  Bloomberg           1
# 2  Buttigieg           1
# 3  Klobuchar           0
# 4    Sanders           0
# 5     Warren           1
#        query  perc_confident
# 0      Biden               3
# 1  Bloomberg               4
# 2  Buttigieg               3
# 3  Klobuchar               5
# 4    Sanders               2
# 5     Warren               5
#        query  perc_fear
# 0      Biden          0
# 1  Bloomberg          0
# 2  Buttigieg          2
# 3  Klobuchar          1
# 4    Sanders          1
# 5     Warren          2
#        query  perc_joy
# 0      Biden        17
# 1  Bloomberg        14
# 2  Buttigieg        19
# 3  Klobuchar        15
# 4    Sanders         9
# 5     Warren        11
#        query  perc_sadness
# 0      Biden             4
# 1  Bloomberg             2
# 2  Buttigieg             7
# 3  Klobuchar             7
# 4    Sanders             3
# 5     Warren             7
#        query  perc_tentative
# 0      Biden              11
# 1  Bloomberg              14
# 2  Buttigieg              11
# 3  Klobuchar              11
# 4    Sanders               8
# 5     Warren              12

# %% [markdown]
# ## Full Text

# %%
tones = ['analytical', 'anger', 'confident', 'fear', 'joy', 'sadness', 'tentative']

for t in tones:
    print(df_articles.drop_duplicates(subset=['url', 'query'])\
        .groupby('query').agg({f'full_text_{t}': 'mean'}).reset_index())
# Out:
#        query  full_text_analytical
# 0      Biden              0.644415
# 1  Bloomberg              0.672291
# 2  Buttigieg              0.675362
# 3  Klobuchar              0.649617
# 4    Sanders              0.691609
# 5     Warren              0.642039
#        query  full_text_anger
# 0      Biden         0.553408
# 1  Bloomberg         0.601881
# 2  Buttigieg         0.581138
# 3  Klobuchar         0.600582
# 4    Sanders         0.582045
# 5     Warren         0.548879
#        query  full_text_confident
# 0      Biden             0.842017
# 1  Bloomberg             0.964027
# 2  Buttigieg             0.742772
# 3  Klobuchar                  NaN
# 4    Sanders             0.780650
# 5     Warren             0.532529
#        query  full_text_fear
# 0      Biden        0.564674
# 1  Bloomberg        0.620495
# 2  Buttigieg        0.523748
# 3  Klobuchar        0.513644
# 4    Sanders        0.538991
# 5     Warren        0.579506
#        query  full_text_joy
# 0      Biden       0.563696
# 1  Bloomberg       0.549207
# 2  Buttigieg       0.563809
# 3  Klobuchar       0.558206
# 4    Sanders       0.557274
# 5     Warren       0.555036
#        query  full_text_sadness
# 0      Biden           0.542444
# 1  Bloomberg           0.547316
# 2  Buttigieg           0.533999
# 3  Klobuchar           0.537497
# 4    Sanders           0.537245
# 5     Warren           0.534144
#        query  full_text_tentative
# 0      Biden             0.663590
# 1  Bloomberg             0.662250
# 2  Buttigieg             0.624488
# 3  Klobuchar             0.637570
# 4    Sanders             0.665470
# 5     Warren             0.623003

# %%
tones = ['analytical', 'anger', 'confident', 'fear', 'joy', 'sadness', 'tentative']

for t in tones:
    print(df_articles.drop_duplicates(subset=['url', 'query'])\
        .groupby('query')['full_text_' + t].apply(lambda s: len(s[s > 0])).reset_index()\
        .rename(columns={f'full_text_{t}': f'perc_{t}'}))
    print('---')
# Out:
#        query  perc_analytical
# 0      Biden               46
# 1  Bloomberg               44
# 2  Buttigieg               40
# 3  Klobuchar               39
# 4    Sanders               51
# 5     Warren               41
# ---
#        query  perc_anger
# 0      Biden           3
# 1  Bloomberg           7
# 2  Buttigieg           3
# 3  Klobuchar           4
# 4    Sanders           1
# 5     Warren           6
# ---
#        query  perc_confident
# 0      Biden               1
# 1  Bloomberg               1
# 2  Buttigieg               2
# 3  Klobuchar               0
# 4    Sanders               4
# 5     Warren               1
# ---
#        query  perc_fear
# 0      Biden          4
# 1  Bloomberg          6
# 2  Buttigieg          1
# 3  Klobuchar          1
# 4    Sanders          4
# 5     Warren          4
# ---
#        query  perc_joy
# 0      Biden        53
# 1  Bloomberg        47
# 2  Buttigieg        56
# 3  Klobuchar        53
# 4    Sanders        44
# 5     Warren        55
# ---
#        query  perc_sadness
# 0      Biden            35
# 1  Bloomberg            36
# 2  Buttigieg            30
# 3  Klobuchar            38
# 4    Sanders            30
# 5     Warren            41
# ---
#        query  perc_tentative
# 0      Biden              27
# 1  Bloomberg              26
# 2  Buttigieg              30
# 3  Klobuchar              32
# 4    Sanders              34
# 5     Warren              31
# ---

# %% [markdown]
# # By Sentences

# %%
# have the first 100 sentences of each article (ish)
# dedupe based on url
# if a candidate is mentioned in the sentence => add one to each tone for that candidate, also add count of sentences

# %%
df_sentences = pd.read_csv('../data/raw/articles_sentences.csv')

# %% [markdown]
# ## Overall Sentence Counts

# %%
candidate_sent_counts = get_total_mentions(df_sentences.drop_duplicates(subset=['url', 'sentence_id']).text.values)
candidate_sent_counts
# Out:
# Counter({'klobuchar': 550,
#          'buttigieg': 741,
#          'sanders': 1399,
#          'biden': 1127,
#          'bloomberg': 1012,
#          'warren': 807})

# %% [markdown]
# ## Average Tone Score

# %%
df_tone_means = pd.DataFrame()
for cand_name in ['biden', 'sanders', 'warren', 'buttigieg', 'klobuchar', 'bloomberg']:
    res = df_sentences.drop_duplicates(subset=['url', 'sentence_id'])\
        [df_sentences.text.str.lower().str.contains(cand_name, na=False)]\
        .drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'sentence_id'])\
        .agg('mean')
    row = pd.DataFrame(res).transpose()
    row['candidate'] = cand_name
    df_tone_means = df_tone_means.append(row)
df_tone_means
# Out:
# /Users/willyraedy/opt/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#    analytical_score  anger_score  confident_score  fear_score  joy_score  \
# 0          0.694990     0.585095         0.695641    0.635482   0.634871
# 0          0.704767     0.583485         0.687286    0.609721   0.619563
# 0          0.688087     0.605417         0.654411    0.627549   0.611048
# 0          0.710062     0.619972         0.689820    0.658083   0.610898
# 0          0.693422     0.556284         0.692522    0.615017   0.626487
# 0          0.693179     0.599626         0.711902    0.625188   0.623037
#
#    sadness_score  tentative_score  candidate
# 0       0.610058         0.726799      biden
# 0       0.595516         0.703899    sanders
# 0       0.598888         0.725236     warren
# 0       0.583380         0.684643  buttigieg
# 0       0.567478         0.731297  klobuchar
# 0       0.606333         0.720134  bloomberg

# %% [markdown]
# ## Count of Sentences

# %%
df_tone_counts = pd.DataFrame()
for cand_name in ['biden', 'sanders', 'warren', 'buttigieg', 'klobuchar', 'bloomberg']:
    res = df_sentences.drop_duplicates(subset=['url', 'sentence_id'])\
        [df_sentences.text.str.lower().str.contains(cand_name, na=False)]\
        .drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'sentence_id'])\
        .agg('count')
    row = pd.DataFrame(res).transpose()
    row['candidate'] = cand_name
    df_tone_counts = df_tone_counts.append(row)
df_tone_counts = df_tone_counts.drop(columns=['url', 'query']).rename(columns={'text': 'total_sentences'})
df_tone_counts
# Out:
# /Users/willyraedy/opt/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#    total_sentences  analytical_score  anger_score  confident_score  \
# 0             1089               292           21               61
# 0             1335               428            8               72
# 0              781               197            7               30
# 0              712               203           10               31
# 0              543               143            4               33
# 0              960               262           24               39
#
#    fear_score  joy_score  sadness_score  tentative_score  candidate
# 0          17        203            117              135      biden
# 0          20        170            116              153    sanders
# 0          10        117             78               89     warren
# 0           5        108             75               68  buttigieg
# 0           6         98             52               58  klobuchar
# 0          16        105             75              101  bloomberg

# %% [markdown]
# ## Percentage of Sentences

# %%
df_tone_perc = df_tone_counts.copy()
for col in df_tone_perc.columns[1:-1]:
    df_tone_perc[col] = df_tone_perc[col] / df_tone_perc['total_sentences']
df_tone_perc
# Out:
#    total_sentences  analytical_score  anger_score  confident_score  \
# 0             1089          0.268136     0.019284         0.056015
# 0             1335          0.320599     0.005993         0.053933
# 0              781          0.252241     0.008963         0.038412
# 0              712          0.285112     0.014045         0.043539
# 0              543          0.263352     0.007366         0.060773
# 0              960          0.272917     0.025000         0.040625
#
#    fear_score  joy_score  sadness_score  tentative_score  candidate
# 0    0.015611   0.186410       0.107438         0.123967      biden
# 0    0.014981   0.127341       0.086891         0.114607    sanders
# 0    0.012804   0.149808       0.099872         0.113956     warren
# 0    0.007022   0.151685       0.105337         0.095506  buttigieg
# 0    0.011050   0.180479       0.095764         0.106814  klobuchar
# 0    0.016667   0.109375       0.078125         0.105208  bloomberg

# %% [markdown]
# # Week Over Week

# %%
merged = df_sentences.merge(df_articles.drop_duplicates(subset=['url'])[['url', 'publishedAt']], on='url', how='left')
merged['publishedAt'] = merged['publishedAt'].map(pd.to_datetime)

# %%
df_tone_counts_wk = pd.DataFrame()
for cand_name in ['biden', 'sanders', 'warren', 'buttigieg', 'klobuchar', 'bloomberg']:
    res = merged.drop_duplicates(subset=['url', 'sentence_id'])\
        [merged.text.str.lower().str.contains(cand_name, na=False)]\
        .drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'sentence_id'])\
        .groupby(merged.publishedAt.dt.week)\
        .agg('count')
    row = pd.DataFrame(res)
    row['candidate'] = cand_name
    df_tone_counts_wk = df_tone_counts_wk.append(row)
df_tone_counts_wk = df_tone_counts_wk.drop(columns=['url', 'query']).rename(columns={'text': 'total_sentences'})
df_tone_counts_wk
# Out:
# /Users/willyraedy/opt/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#              total_sentences  analytical_score  anger_score  confident_score  \
# publishedAt
# 6                        281                79            8               12
# 7                        216                55            6                9
# 8                        168                46            2                7
# 9                        344                93            5               27
# 10                        80                19            0                6
# 6                        221                59            1                9
# 7                        217                60            0               12
# 8                        392               139            2               23
# 9                        445               155            5               27
# 10                        60                15            0                1
# 6                        109                33            0                4
# 7                        172                45            2                6
# 8                        244                51            2               10
# 9                        208                56            2                8
# 10                        48                12            1                2
# 6                        228                68            3                9
# 7                        164                54            0                5
# 8                        178                51            7               11
# 9                         94                21            0                3
# 10                        48                 9            0                3
# 6                         98                27            1                5
# 7                        217                67            1               10
# 8                        158                34            1               12
# 9                         42                13            1                3
# 10                        28                 2            0                3
# 6                         41                10            1                1
# 7                        173                53            3                6
# 8                        463               127           14               20
# 9                        252                65            4               11
# 10                        31                 7            2                1
#
#              fear_score  joy_score  sadness_score  tentative_score  \
# publishedAt
# 6                     6         43             36               38
# 7                     3         45             29               25
# 8                     4         22             10               21
# 9                     4         74             36               46
# 10                    0         19              6                5
# 6                     0         25             17               24
# 7                     6         42             22               26
# 8                     5         49             18               50
# 9                     6         43             55               51
# 10                    3         11              4                2
# 6                     1         23             14               12
# 7                     3         44             12               21
# 8                     2         22             19               25
# 9                     1         20             25               25
# 10                    3          8              8                6
# 6                     2         41             21               22
# 7                     2         28             26               15
# 8                     1         19             10               18
# 9                     0         13             10               10
# 10                    0          7              8                3
# 6                     0         15              8               11
# 7                     2         45             24               21
# 8                     3         30             15               19
# 9                     1          3              3                5
# 10                    0          5              2                2
# 6                     0          9              6                4
# 7                     2         26             18               16
# 8                     9         49             28               54
# 9                     4         19             19               22
# 10                    1          2              4                5
#
#              publishedAt  candidate
# publishedAt
# 6                    281      biden
# 7                    216      biden
# 8                    168      biden
# 9                    344      biden
# 10                    80      biden
# 6                    221    sanders
# 7                    217    sanders
# 8                    392    sanders
# 9                    445    sanders
# 10                    60    sanders
# 6                    109     warren
# 7                    172     warren
# 8                    244     warren
# 9                    208     warren
# 10                    48     warren
# 6                    228  buttigieg
# 7                    164  buttigieg
# 8                    178  buttigieg
# 9                     94  buttigieg
# 10                    48  buttigieg
# 6                     98  klobuchar
# 7                    217  klobuchar
# 8                    158  klobuchar
# 9                     42  klobuchar
# 10                    28  klobuchar
# 6                     41  bloomberg
# 7                    173  bloomberg
# 8                    463  bloomberg
# 9                    252  bloomberg
# 10                    31  bloomberg

# %%
df_tone_perc_wk = df_tone_counts_wk.copy()
for col in df_tone_perc_wk.columns[1:-1]:
    df_tone_perc_wk[col] = df_tone_perc_wk[col] / df_tone_perc_wk['total_sentences']
df_tone_perc_wk
# Out:
#              total_sentences  analytical_score  anger_score  confident_score  \
# publishedAt
# 6                        281          0.281139     0.028470         0.042705
# 7                        216          0.254630     0.027778         0.041667
# 8                        168          0.273810     0.011905         0.041667
# 9                        344          0.270349     0.014535         0.078488
# 10                        80          0.237500     0.000000         0.075000
# 6                        221          0.266968     0.004525         0.040724
# 7                        217          0.276498     0.000000         0.055300
# 8                        392          0.354592     0.005102         0.058673
# 9                        445          0.348315     0.011236         0.060674
# 10                        60          0.250000     0.000000         0.016667
# 6                        109          0.302752     0.000000         0.036697
# 7                        172          0.261628     0.011628         0.034884
# 8                        244          0.209016     0.008197         0.040984
# 9                        208          0.269231     0.009615         0.038462
# 10                        48          0.250000     0.020833         0.041667
# 6                        228          0.298246     0.013158         0.039474
# 7                        164          0.329268     0.000000         0.030488
# 8                        178          0.286517     0.039326         0.061798
# 9                         94          0.223404     0.000000         0.031915
# 10                        48          0.187500     0.000000         0.062500
# 6                         98          0.275510     0.010204         0.051020
# 7                        217          0.308756     0.004608         0.046083
# 8                        158          0.215190     0.006329         0.075949
# 9                         42          0.309524     0.023810         0.071429
# 10                        28          0.071429     0.000000         0.107143
# 6                         41          0.243902     0.024390         0.024390
# 7                        173          0.306358     0.017341         0.034682
# 8                        463          0.274298     0.030238         0.043197
# 9                        252          0.257937     0.015873         0.043651
# 10                        31          0.225806     0.064516         0.032258
#
#              fear_score  joy_score  sadness_score  tentative_score  \
# publishedAt
# 6              0.021352   0.153025       0.128114         0.135231
# 7              0.013889   0.208333       0.134259         0.115741
# 8              0.023810   0.130952       0.059524         0.125000
# 9              0.011628   0.215116       0.104651         0.133721
# 10             0.000000   0.237500       0.075000         0.062500
# 6              0.000000   0.113122       0.076923         0.108597
# 7              0.027650   0.193548       0.101382         0.119816
# 8              0.012755   0.125000       0.045918         0.127551
# 9              0.013483   0.096629       0.123596         0.114607
# 10             0.050000   0.183333       0.066667         0.033333
# 6              0.009174   0.211009       0.128440         0.110092
# 7              0.017442   0.255814       0.069767         0.122093
# 8              0.008197   0.090164       0.077869         0.102459
# 9              0.004808   0.096154       0.120192         0.120192
# 10             0.062500   0.166667       0.166667         0.125000
# 6              0.008772   0.179825       0.092105         0.096491
# 7              0.012195   0.170732       0.158537         0.091463
# 8              0.005618   0.106742       0.056180         0.101124
# 9              0.000000   0.138298       0.106383         0.106383
# 10             0.000000   0.145833       0.166667         0.062500
# 6              0.000000   0.153061       0.081633         0.112245
# 7              0.009217   0.207373       0.110599         0.096774
# 8              0.018987   0.189873       0.094937         0.120253
# 9              0.023810   0.071429       0.071429         0.119048
# 10             0.000000   0.178571       0.071429         0.071429
# 6              0.000000   0.219512       0.146341         0.097561
# 7              0.011561   0.150289       0.104046         0.092486
# 8              0.019438   0.105832       0.060475         0.116631
# 9              0.015873   0.075397       0.075397         0.087302
# 10             0.032258   0.064516       0.129032         0.161290
#
#              publishedAt  candidate
# publishedAt
# 6                    1.0      biden
# 7                    1.0      biden
# 8                    1.0      biden
# 9                    1.0      biden
# 10                   1.0      biden
# 6                    1.0    sanders
# 7                    1.0    sanders
# 8                    1.0    sanders
# 9                    1.0    sanders
# 10                   1.0    sanders
# 6                    1.0     warren
# 7                    1.0     warren
# 8                    1.0     warren
# 9                    1.0     warren
# 10                   1.0     warren
# 6                    1.0  buttigieg
# 7                    1.0  buttigieg
# 8                    1.0  buttigieg
# 9                    1.0  buttigieg
# 10                   1.0  buttigieg
# 6                    1.0  klobuchar
# 7                    1.0  klobuchar
# 8                    1.0  klobuchar
# 9                    1.0  klobuchar
# 10                   1.0  klobuchar
# 6                    1.0  bloomberg
# 7                    1.0  bloomberg
# 8                    1.0  bloomberg
# 9                    1.0  bloomberg
# 10                   1.0  bloomberg
